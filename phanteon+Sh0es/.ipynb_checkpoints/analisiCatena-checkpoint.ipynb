# %%
import matplotlib.pyplot as plt
import numpy as np
import getdist,os
from getdist import plots, MCSamples,mcsamples,loadMCSamples

# %%
rootpath = os.path.join(os.getcwd(),'samples300/samples300')

# %%
samples = loadMCSamples(rootpath)

# %%
g = plots.get_subplot_plotter()
g.triangle_plot(samples, filled=True,title_limit=1,)
 # first title limit (for 1D plots) is 68% by default

# %%
samples.removeBurn(10000)
g = plots.get_subplot_plotter()
g.triangle_plot(samples, filled=True,title_limit=1,)
# Out:
# WARNING:root:auto bandwidth for \Omega_m very small or failed (h=0.0001008768070721806,N_eff=30586.180629261937). Using fallback (h=0.007816259086586407)
# WARNING:root:auto bandwidth for \Omega_m very small or failed (h=0.0001008768070721806,N_eff=30586.180629261937). Using fallback (h=0.007816259086586407)
# WARNING:root:2D kernel density bandwidth optimizer failed for h, \Omega_m. Using fallback width: f(a) and f(b) must have different signs

# %%
parNum = 2;
fig, axes = plt.subplots(parNum, figsize=(10, 7), sharex=True)
labelsPar = ["$h$", "$\Omega_m$"]
for i in range(parNum):
    ax = axes[i]
    ax.plot(samples[i], "k", alpha=0.9)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labelsPar[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel("step number");
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 7
#       5 ax = axes[i]
#       6 ax.plot(samples[i], "k", alpha=0.3)
# ----> 7 ax.set_xlim(0, len(samples))
#       8 ax.set_ylabel(labelsPar[i])
#       9 ax.yaxis.set_label_coords(-0.1, 0.5)
#
# TypeError: object of type 'MCSamples' has no len()

# %%
samples[0]
# Out:
# array([0.7235727, 0.7235727, 0.7235727, ..., 0.7336068, 0.7336068,
#        0.7336068])
